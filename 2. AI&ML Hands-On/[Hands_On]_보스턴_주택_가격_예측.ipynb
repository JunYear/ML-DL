# %% [markdown]
# <a href="https://colab.research.google.com/github/JunYear/ML-DL/blob/main/2.%20AI%26ML%20Hands-On/%5BHands_On%5D_%EB%B3%B4%EC%8A%A4%ED%84%B4_%EC%A3%BC%ED%83%9D_%EA%B0%80%EA%B2%A9_%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.datasets.boston_housing import load_data

(X_train, y_train), (X_test, y_test) = load_data(path='boston_housing.npz',
                                                 test_split=0.2,
                                                 seed=777)
# Out:
# ...
# 57026/57026 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (404, 13) (404,)
# (102, 13) (102,)

# %%
import numpy as np

mean = np.mean(X_train, axis=0)
std = np.std(X_train, axis=0)

X_train = (X_train - mean) / std
X_test = (X_test - mean) / std

from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train,
                                                  test_size=0.33,
                                                  random_state=777)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Dense(64, activation = 'relu', input_shape = (13, )))
model.add(Dense(32, activation = 'relu'))
model.add(Dense(1))

model.compile(optimizer = 'adam', loss = 'mse', metrics = ['mae'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(X_train, y_train, epochs=300,
                    validation_data = (X_val, y_val))
model.evaluate(X_test, y_test)
# Out:
# Epoch 1/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 550.0715 - mae: 21.9628 - val_loss: 621.3766 - val_mae: 22.6533
# Epoch 2/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 556.6372 - mae: 21.8713 - val_loss: 592.2755 - val_mae: 22.0153
# Epoch 3/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 524.4823 - mae: 21.1882 - val_loss: 563.2675 - val_mae: 21.3656
# Epoch 4/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 517.5883 - mae: 20.8457 - val_loss: 531.6960 - val_mae: 20.6404
# Epoch 5/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 436.5622 - mae: 19.1623 - val_loss: 495.1230 - val_mae: 19.7712
# Epoch 6/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 432.6578 - mae: 18.6538 - val_loss: 451.0244 - val_mae: 18.6891
# Epoch 7/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 384.1520 - mae: 17.8806 - val_loss: 399.7487 - val_mae: 17.3605
# Epoch 8/300
# ...

# %%
from tensorflow.keras.datasets.boston_housing import load_data
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import numpy as np
from sklearn.model_selection import KFold

(X_train, y_train), (X_test, y_test) = load_data(path='boston_housing.npz',
                                                 test_split=0.2,
                                                 seed=777)

mean = np.mean(X_train, axis=0)
std = np.std(X_train, axis=0)

X_train = (X_train - mean) / std
X_test = (X_test - mean) / std

k = 3

kfold = KFold(n_splits = k, shuffle = True, random_state = 777)

def get_model():
  model = Sequential()
  model.add(Dense(64, activation='relu', input_shape = (13, )))
  model.add(Dense(32, activation = 'relu'))
  model.add(Dense(1))

  model.compile(optimizer = 'adam', loss = 'mse', metrics = ['mae'])

  return model

mae_list = []

for train_index, val_index in kfold.split(X_train):
  X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
  y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

  model = get_model()

  model.fit(X_train_fold, y_train_fold, epochs=300,
            validation_data = (X_val_fold, y_val_fold))

  _, test_mae = model.evaluate(X_test, y_test)
  mae_list.append(test_mae)
# Out:
# Epoch 1/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 535.2052 - mae: 21.4110 - val_loss: 565.8683 - val_mae: 21.5709
# Epoch 2/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 470.9644 - mae: 19.9945 - val_loss: 528.6268 - val_mae: 20.7348
# Epoch 3/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 458.7183 - mae: 19.9247 - val_loss: 484.0701 - val_mae: 19.6977
# Epoch 4/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 411.6057 - mae: 18.4747 - val_loss: 429.2096 - val_mae: 18.3483
# Epoch 5/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 376.3119 - mae: 17.4234 - val_loss: 363.4594 - val_mae: 16.5910
# Epoch 6/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 308.3040 - mae: 15.5295 - val_loss: 288.8428 - val_mae: 14.3760
# Epoch 7/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 224.0884 - mae: 13.2167 - val_loss: 216.0415 - val_mae: 11.8932
# Epoch 8/300
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 158.2070 - mae: 10.6832 - val_loss: 153.7142 - val_mae: 9.4005
# ...

# %%
print(mae_list)
# Out:
# [2.245551109313965, 2.2201318740844727, 2.215367078781128]

# %%
print(np.mean(mae_list))
# Out:
# 2.2270166873931885
